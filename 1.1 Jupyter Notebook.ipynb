# %% [markdown]
# # Jupyter Notebook: навигация

# %% [markdown]
# Основной элемент Jupyter  — ячейки. Они бывают двух типов:
#
# ячейки с кодом (code cells)
# ячейки с текстом (markdown cells)
# Ячейки можно создавать, удалять, запускать, перемещать вверх-вниз.

# %% [markdown]
# **Работа с ячейками:**
#
# Выбор ячейки — нажмите на нее мышкой.
#
# Редактирование — нажмите на нее два раза.
#
# Запуск ячейки — `SHIFT+ENTER` или нажмите на кнопку  на панеле.
#
# Добавление новой ячейки — нажмите на кнопку  на панеле.
#
# Удаление ячейки — нажмите на кнопку  на панеле.
#
# Перемещение ячейки — нажмите на вертикальные стрелки.
#
# И много другое в `Help => Keyboarn shortcuts`.

# %% [markdown]
# ## **Стиль офомления кода**

# %% [markdown]
# PEP8:
#
# отступ – 4 пробела
# длина строки < 80 символов
# переменные: var_recommended NOT VarRecommended
# константы/вводные переменный: CONST_RECOMMENDED (например пути к папкам, которые не меняются)

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # **О Python**

# %% [markdown]
# Название - «Питон» или «Пайтон» (в честь комедийных серий BBC «Летающий цирк Монти-Пайтона»)
# Создатель - голландец Гвидо ван Россум (Guido van Rossum) (в 1991 году)
#
# Особенности:
#
# >интерпретируемый (читается интерпритатором построчно)
#
# >объектно-ориентированный (всё в Python это объект)
#
# >высокоуровневый язык (ближе к человеческому)
#
# >динамическая типизация (не нужно указывать тип данных и в переменную можно переназначать значения с разными типами данных)
#
# >синтаксис прост в изучении
#
# >поддержка модулей и пакетов (большинство библиотек бесплатны)
#
# >универсальный
#
# >интеграция с другими языками (C (Cython), C++, Java (JPython))

# %% [markdown]
# ## **Переменные**

# %%
number_1 = 1

# %%
a
# Out:
# 1

# %% [markdown]
# Для доступа к объекту предназначены переменные.
# В языке Python все переменные являются ссылками на
# объекты.
# В Python при инициализации в переменной сохраняется ссылка
# (адрес объекта в памяти компьютера) на объект.
# Благодаря этой ссылке можно в дальнейшем использовать
# объект из программы.
# В Python для присвоения используется = (для сравнения
# значений на равенство используется == ). Первое присвоение
# значения переменной создает ее. Нет необходимости
# декларировать тип переменной (он определяется
# автоматически - по типу присваиваемого объекта).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# При создании программ для работы с данными используют переменные и константы, которые, как известно, имеют три характеристики: имя, тип и значение. Если значение константы неизменно, то значение переменной может меняться в процессе исполнения программы.

# %%
z=23
z

# %%
z='пример'
z

# %%
my_number

# %% [markdown]
# ## **Имена переменных**

# %% [markdown]
# Для доступа к данным используется переменная.
# Каждая переменная имеет имя.
# Имя переменной (идентификатор) состоит из букв, цифр
# символов подчеркивания. Имя не может начинаться с цифры.
# В качестве имен нельзя использовать ключевые слова
# языка.
# Следует избегать совпадения имен с уже имеющимися в
# системе, например, с именами функций. Так как это может
# привести к ошибкам.
# В редакторе IDLE цвет переменной должен быть черным.
# В именах нужно учитывать регистр букв.
# Правильные имена: x1, X1, MyData, my_data.
#
# **Неправильные имена:** 2y, x*, class.
#
# **Плохие имена:** str, МояПеременная, _x

# %% [markdown]
# ## **Типы данных**

# %% [markdown]
# Как известно, переменные
# предназначены для возможности
# осуществления доступа к данным.
# Данные могут быть различных типов.
# Тип данных указывает, какие значения
# может принимать переменная, а
# также, какие операции можно
# выполнять с переменными.
# Язык программирования Python
# поддерживает 12 типов данных.
# Перечислим те из них, с которыми
# нам предстоит работать

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
type(25)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
type('Hello, world!')
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
type([1,2,4,5,2,4])
# Out:
# list

# %%
type({'a': 2,'b': 23})
# Out:
# dict

# %%
type((1,23,4,23,12))
# Out:
# tuple

# %%
type({1,2,3,4})
# Out:
# set

# %% [markdown]
# ## **Динамическая типизация**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# в Python есть специальные ***функции***, которые приводят данные к нужному нам типу. Вот они:
#
#
#  - целые числа       — `int()`
#  - дробные числа     —  `float()`
#  - логические флаги   —  `bool()`
#  - строки             —  `str()`

# %%
a = 6
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(float(a)))
# Out:
# <class 'float'>

# %%
type(str(a))
# Out:
# str

# %%
print(a)
# Out:
# 6

# %%
type(int(a))
# Out:
# int

# %% [markdown]
# ## **Инструкция print()**

# %% [markdown]
# Чтобы значение некоторой
# переменной было выведено на
# экран, используется инструкция print().
# Для этого имя переменной
# указывается внутри скобок
# инструкции print(), но в кавычки
# не заключается, поскольку
# нужно вывести на экран
# значение переменной, а не ее
# имя.
# Инструкция print позволяет
# выводить на экран не только
# текст и значения переменных,
# заданных или вычисленных в
# программе ранее

# %%
print('Hello,world!')
# Out:
# Hello,world!

# %% [markdown]
# В круглых скобках инструкции
# print может быть и выражение.
# Если на экран необходимо
# вывести значение этого
# выражения, естественно, при
# условии, что это значение
# определено, то тогда это
# выражение записывается без
# кавычек.
# Если на экран хотим вывести
# саму запись выражения, то тогда
# это выражение следует написать
# в кавычках.

# %%
print(2+2)
# Out:
# 4

# %%
print('2+2')
# Out:
# 2+2

# %%
print(a)
# Out:
# 6

# %% [markdown]
# Если инструкция print()
# отвечает за вывод данных,
# то за ввод данных отвечает
# инструкция input().
# Инструкция input() ожидает
# ввода с клавиатуры
# последовательности
# символов. После их набора
# и нажатия клавиши Enter из
# этих символов формируется
# упорядоченная
# последовательность
# символов, называемая
# строкой.

# %%
input()
# Out:
# 21
# '21'

# %% [markdown]
# ## **Операции над числами**

# %% [markdown]
# Рассмотрим теперь более детально
# работу с числами и числовыми
# выражениями.
# Синтаксис числовых выражений в
# языке Python привычен: операции
# сложения, вычитания, умножения и
# вещественного деления
# обозначаются так же, как и в других
# языках программирования; для
# группировки используются скобки.
# Возведение в степень в языке Python
# обозначается двумя звёздочками. Для
# целочисленного деления
# используются следующие
# обозначения: два знака «слэш» -
# целая часть от деления, знак
# «процент» - остаток от деления.

# %%
print(2+12)
print(2*3)
print(121%3) # остаток от деления 
print(121//3) # целочисленное деление
print(121/3) # деление с остатком
print(2**6) # возведение в степень
print(4**0.5) #корень из числа
print(abs(-1312)) #модуль числа
print(round(3.143213,2)) #округление
# Out:
# 14
# 6
# 1
# 40
# 40.333333333333336
# 64
# 2.0
# 1312
# 3.14

# %% [markdown]
# ### **Арифметические операторы и строки**

# %%
a='2'
b='2'

# %%
print(a+b)
# Out:
# 22

# %%
name = "3"
print(name*3)
# Out:
# 333

# %%
a = 2
b = 4

print(a == b) # равно
print(a != b) # не равно 
print(a > b) #больше
print(a < b) #меньше
print(a >= b) #больше или равно
print(a <= b) #меньше или равно
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ## **Операторы присваивания**

# %% [markdown]
# Кроме стандартным образом
# оформленных математических
# операций, в языке Python можно
# использовать краткую запись
# некоторых арифметических
# выражений.
# Так, инструкция, означающая, что
# прежнее значение переменной A
# должно быть увеличено на N,
# может быть записана в виде
# A+=N. Аналогичен синтаксис для
# всех подобных операций, если
# новое значение переменной
# вычисляется по старому
# значению за одно
# арифметическое действие.

# %% [markdown]
# <img style='float:left' src="https://res.cloudinary.com/djcwxgbfz/image/upload/v1611402764/skills/30.png" width="500"/>

# %%
# иногда нам регулярно нужно добавлять какие-то значения в одну переменную

a = 2
b = a + 3
print(b)

# %%
# тот же результат даст оператор присваивания
a = 2
a += 3
print(a)

# %% [markdown]
# Операторы присваивания всегда переписывают значение переменной. Если нам нужно сохранить старые значения, их можно положить в отдельную переменную, но обязательно перед запуском оператора присваивания.

# %% [markdown]
# ## **Математические библиотеки**

# %% [markdown]
# Помимо стандартных
# арифметических операций, при
# работе с числами мы можем
# использовать математические
# функции, встроенные в модули
# языка Python.
# Богатая стандартная
# библиотека модулей является
# одной из привлекательных
# сторон языка
# программирования Python.
# Для того, чтобы получить
# возможность использовать
# функции модулей, эти модули
# необходимо импортировать из
# библиотеки в свою программу.
# Это действие осуществляется
# инструкцией import,
# помещаемой в начало
# программы

# %%
import math

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Для того чтобы использовать в
# программе какую-либо функцию из
# модуля, нужно указать имя модуля, далее
# через точку имя вызываемой функции и
# в скобках – аргументы вызываемой
# функции.

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.factorial(10)
# Out:
# 3628800

# %%
math.pow(5,2)
# Out:
# 25.0
